# %%
include("../src/ExpMap.jl")
# Out:
# Main.ExpMap

# %%
using .ExpMap

# %%
H = Vector{NodeFrame}(undef,4)
H[1] = NodeFrame(VEC3(0.0, 0.6, 0.0), RV3(0.0, 0.0, 0.0))
H[2] = NodeFrame(VEC3(0.0, 0.5500000000000432, 0.0), RV3(0.0, 0.0, 0.0))
H[3] = NodeFrame(VEC3(0.05000000000002842, 0.5500000000000874, 0.0), RV3(0.0, 0.0, 0.0))
H[4] = NodeFrame(VEC3(0.05000000000013695, 0.6, 0.0), RV3(0.0, 0.0, 0.0))
# Out:
# NodeFrame(VEC3(0.05000000000013695, 0.6, 0.0), RV3(0.0, 0.0, 0.0))

# %%
x = zeros(2)
F, DF = shape_functions_2D(4,x)
# Out:
# UndefVarError: `A` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Projects/Julia/ExpMap/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sdnNjb2RlLXJlbW90ZQ==.jl:2
